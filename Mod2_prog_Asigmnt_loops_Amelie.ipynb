# %% [markdown]
# ## Amelie
# This code demonstrates some concepts in Python, such as choosing a number, using if/else statements, working with variables, assigning and modifying variables.

# %% [markdown]
# In the following section, we assign a number between 1 and 10 to a variable.

# %%
# 4.1 Choose a number between 1 and 10
number = 7 
print ("The chosen number is:", number)
# Out:
# The chosen number is: 7

# %% [markdown]
# The following section demonstrates how to use if/else conditions to compare values.

# %%
# 4.2 If/Else statements 
number = 7 
if number < 5:
    print ("The number is less than 5")
elif number ==5:
    print ("The number is equal to 5")
else: 
    print("The number is greater than 5")
# Out:
# The number is greater than 5

# %% [markdown]
# The following section uses a for loop to iterate through a list and print each value

# %%
# 6.1 Using Loop
my_list = [1, 2, 3, 4, 5] 
for item in my_list:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# The following section assigns the value 7 to a variable named guess_me

# %%
# 6.2 Let's assign the value 7 to guess_me 
guess_me = 7 
print("guess_me is:", guess_me)
# Out:
# guess_me is: 7

# %% [markdown]
# The following section changes the value of guess_me to 5.

# %%
# 6.3 Let's assign the value 5 to guess_me 
guess_me = 5
print("guess_me is:", guess_me)
# Out:
# guess_me is: 5
