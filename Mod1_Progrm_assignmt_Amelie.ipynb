# %% [markdown]
# ## Name: Amelie
# ## Description: This notebook calculates the number of seconds per hour and per day using Python

# %%
# 3.1 Number of seconds in an hour
60 * 60
# Out:
# 3600

# %%
# 3.2 The value is stored in a variable called seconds_per_hour
seconds_per_hour = 3600

# %%
# 3.3  Number of seconds in a day
seconds_per_hour * 24
# Out:
# 86400

# %%
# 3.4 The result is stored in a variable called seconds_per_day
seconds_per_day = seconds_per_hour * 24

# %%
# 3.5 We divide seconds per day by seconds per hour
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
# 3.6 Let's divide seconds_per_day by seconds_per_hour
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# # Yes, the result agrees with the previous value. The only difference is that integer division returns 24 instead of 24.0.
